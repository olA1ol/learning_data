# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
## csv 폴더 안에 있는 drinks.csv 파일을 로드
drinks = pd.read_csv("../data/csv/drinks.csv")

# %%
drinks.describe()
# Out:
#        beer_servings  spirit_servings  wine_servings  \
# count     193.000000       193.000000     193.000000
# mean      106.160622        80.994819      49.450777
# std       101.143103        88.284312      79.697598
# min         0.000000         0.000000       0.000000
# 25%        20.000000         4.000000       1.000000
# 50%        76.000000        56.000000       8.000000
# 75%       188.000000       128.000000      59.000000
# max       376.000000       438.000000     370.000000
#
#        total_litres_of_pure_alcohol
# count                    193.000000
# mean                       4.717098
# std                        3.773298
# min                        0.000000
# 25%                        1.300000
# 50%                        4.200000
# 75%                        7.200000
# max                       14.400000

# %%
drinks.head(3)
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0        AS
# 1                           4.9        EU
# 2                           0.7        AF

# %%
## 상관 계수를 출력
corr = drinks[
    ['beer_servings', 'spirit_servings', 
     'wine_servings', 'total_litres_of_pure_alcohol']
].corr(method='pearson')
corr
# Out:
#                               beer_servings  spirit_servings  wine_servings  \
# beer_servings                      1.000000         0.458819       0.527172
# spirit_servings                    0.458819         1.000000       0.194797
# wine_servings                      0.527172         0.194797       1.000000
# total_litres_of_pure_alcohol       0.835839         0.654968       0.667598
#
#                               total_litres_of_pure_alcohol
# beer_servings                                     0.835839
# spirit_servings                                   0.654968
# wine_servings                                     0.667598
# total_litres_of_pure_alcohol                      1.000000

# %%
# 히트맵 출력
cols_view = ['beer', 'spirit', 'wine', 'alcohol']

hm = sns.heatmap(
    corr.values, 
    cbar = True, ## 사이드바 존재 유무
    annot = True, # 히트맵에 수치를 표시
    square = True, # 히트맵을 정사각형으로 표시
    fmt = '.3f', # 수치의 소수점 자리수
    annot_kws = {'size' : 20}, # 수치의 폰트 사이즈 지정
    xticklabels=cols_view,
    yticklabels=cols_view
)
plt.tight_layout()
plt.show()

# %%
# 히트맵 출력
cols_view = ['beer', 'spirit', 'wine', 'alcohol']

hm = sns.heatmap(
    corr.values, 
    cbar = True, ## 사이드바 존재 유무
    annot = False, # 히트맵에 수치를 표시
    square = False, # 히트맵을 정사각형으로 표시
    fmt = '.3f', # 수치의 소수점 자리수
    annot_kws = {'size' : 20}, # 수치의 폰트 사이즈 지정
    xticklabels=cols_view,
    yticklabels=cols_view
)
plt.tight_layout()
plt.show()

# %%
sns.pairplot(
        drinks.loc[:, 'beer_servings' : 'total_litres_of_pure_alcohol'],
        height = 2.5
)
plt.show()

# %%
sns.pairplot(
    drinks.loc[:, 'beer_servings' : 'total_litres_of_pure_alcohol'],
    height = 2.5,
    kind='reg',
    corner=True,
    plot_kws={
        'line_kws' : {
            'color': 'red'
        }
    }
)
plt.show()
